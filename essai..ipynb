# %%
import pandas as pd

df=pd.read_excel("GCMKCRC26_Collar_Undrilled_240626.xlsx")

# %%
df.head()
# Out:
#       BHID      XCOLLAR      YCOLLAR  ZCOLLAR  LENGTH  BRG  DIP  COMMENTS  \
# 0  CT10_12  242012.9634  1379527.449      139      22  115   60       NaN
# 1  CT10_16  241869.0558  1379589.395      121      54  115   60       NaN
# 2  CT10_17  241859.0288  1379593.711      119      63  115   60       NaN
# 3  CT10_18  241847.0206  1379598.880      120      75  115   60       NaN
# 4  CT10_19  241835.9284  1379603.654      118      85  115   60       NaN
#
#       STATUT    Statuts
# 0  Undrilled  Undrilled
# 1  Undrilled  Undrilled
# 2  Undrilled  Undrilled
# 3  Undrilled  Undrilled
# 4  Undrilled  Undrilled

# %%
# filtrer le fichier avec des Zcollar  suppérieur à 100 en demandant à l'utilisateur de saisir la valeur de Zcollar
zcollar_value = float(input("Entrez la valeur de Zcollar : "))
df_filtered = df[df['ZCOLLAR'] > zcollar_value]
df_filtered.head()
